# %% [markdown]
# ### In this notebook I found top n brick kilns tiles which have the highest number of brick kilns in them.

# %%
import os

# %%
def get_files_with_most_labels(directory):
    labels_count = {}
    for filename in os.listdir(directory):
        # print(filename)
        if filename.endswith(".txt"):
            file_path=os.path.join(directory, filename)
            with open(file_path, "r") as file:
                label_count=len(file.readlines())
                labels_count[filename] = label_count

    sorted_files = sorted(labels_count.items(), key=lambda x: x[1], reverse=True)
    if sorted_files:
        most_labels_file = sorted_files[0][0]
        return most_labels_file,sorted_files
    else:
        return None, []

# %%
directory = '/home/patel_zeel/kiln_compass_24/data/lucknow_airshed/labels/'

most_labels_file, sorted_files = get_files_with_most_labels(directory)

if most_labels_file:
    print(f"File with the most labels: {most_labels_file}")
    print("All files sorted by label count in descending order:")
    for file, count in sorted_files:
        print(f"{file}: {count} labels")
else:
    print("No label files found.")
# Out:
# File with the most labels: 9021406_3115876.txt
# All files sorted by label count in descending order:
# 9021406_3115876.txt: 12 labels
# 8988385_3137890.txt: 12 labels
# 9040668_3088359.txt: 12 labels
# 9032413_3107621.txt: 11 labels
# 9004895_3118628.txt: 11 labels
# 9035164_3091111.txt: 11 labels
# 9002144_3118628.txt: 11 labels
# 8988385_3140642.txt: 10 labels
# 9037916_3088359.txt: 10 labels
# 9035164_3088359.txt: 10 labels
# 9024157_3085607.txt: 10 labels
# 9021406_3113124.txt: 9 labels
# 9029661_3107621.txt: 9 labels
# 8999392_3082855.txt: 9 labels
# 8999392_3085607.txt: 8 labels
# 9021406_3118628.txt: 8 labels
# 9024157_3115876.txt: 7 labels
# 9037916_3107621.txt: 6 labels
# 8985633_3140642.txt: 6 labels
# 8993888_3082855.txt: 6 labels
# 9029661_3096614.txt: 6 labels
# 8996640_3082855.txt: 5 labels
# 9007647_3088359.txt: 5 labels
# 9035164_3107621.txt: 5 labels
# 9007647_3118628.txt: 5 labels
# 9007647_3126883.txt: 5 labels
# 9018654_3093862.txt: 5 labels
# 9032413_3085607.txt: 5 labels
# 9018654_3113124.txt: 5 labels
# 9029661_3121380.txt: 4 labels
# 9035164_3104869.txt: 4 labels
# 9024157_3099366.txt: 4 labels
# 9024157_3088359.txt: 4 labels
# 9029661_3110373.txt: 4 labels
# 9035164_3110373.txt: 4 labels
# 9040668_3110373.txt: 4 labels
# 9032413_3091111.txt: 4 labels
# 9032413_3088359.txt: 4 labels
# 9032413_3096614.txt: 4 labels
# 9035164_3093862.txt: 4 labels
# 9013151_3088359.txt: 3 labels
# 9040668_3118628.txt: 3 labels
# 8982881_3146145.txt: 3 labels
# 8985633_3137890.txt: 3 labels
# 9037916_3085607.txt: 3 labels
# 9002144_3137890.txt: 3 labels
# 9010399_3088359.txt: 3 labels
# 8999392_3140642.txt: 3 labels
# 9024157_3118628.txt: 3 labels
# 9010399_3085607.txt: 3 labels
# 9010399_3126883.txt: 3 labels
# 9010399_3082855.txt: 3 labels
# 9004895_3126883.txt: 3 labels
# 9021406_3096614.txt: 3 labels
# 9035164_3102117.txt: 3 labels
# 9035164_3085607.txt: 3 labels
# 9032413_3104869.txt: 3 labels
# 9021406_3110373.txt: 3 labels
# 9037916_3102117.txt: 3 labels
# 9035164_3115876.txt: 3 labels
# 9013151_3115876.txt: 3 labels
# 9037916_3099366.txt: 3 labels
# 8993888_3085607.txt: 3 labels
# 8996640_3088359.txt: 1 labels
# 9002144_3146145.txt: 1 labels
# 8982881_3140642.txt: 1 labels
# 9029661_3088359.txt: 1 labels
# 8993888_3137890.txt: 1 labels
# 9004895_3146145.txt: 1 labels
# 9013151_3113124.txt: 1 labels
# 9018654_3091111.txt: 1 labels
# 9026909_3110373.txt: 1 labels
# 9010399_3077352.txt: 1 labels
# 9029661_3091111.txt: 1 labels
# 9037916_3129635.txt: 1 labels
# 8985633_3080104.txt: 1 labels
# 9029661_3137890.txt: 1 labels
# 9007647_3146145.txt: 1 labels
# 9007647_3140642.txt: 1 labels
# 9040668_3099366.txt: 1 labels
# 9037916_3121380.txt: 1 labels
# 9029661_3146145.txt: 1 labels
# 9024157_3121380.txt: 1 labels
# 9040668_3113124.txt: 1 labels

# %%
#checking the output correct or not
#File with the most labels: 9021406_3115876.txt
#reading the file
file_path=os.path.join(directory, most_labels_file)
with open(file_path, "r") as file:
    # print(file.readlines())
    print(len(file.readlines()))
# Out:
# 12

# %%
# selct top 15 files with most labels and copy them to another directory
top_files = sorted_files[:15]
copy_dir="../data/vlm_data/lucknow_airshed_most_15/labels/"
os.makedirs(copy_dir, exist_ok=True)
for file, count in top_files:
    src_file_path=os.path.join(directory, file)
    dst_file_path=os.path.join(copy_dir, file)
    os.system(f"cp {src_file_path} {dst_file_path}")

# %%
state_name="lucknow_airshed"
destination_region='lucknow_airshed_most_15'
label_dir = f"../data/vlm_data/lucknow_airshed_most_15/labels"
source_image_dir = f"/home/patel_zeel/kiln_compass_24/data/{state_name}/images"
destination_image_dir = f"../data/vlm_data/{destination_region}/images"

# Create destination directory if it doesn't exist
os.makedirs(destination_image_dir, exist_ok=True)

# Iterate over all .txt files in the label directory
for label_file in os.listdir(label_dir):
    if label_file.endswith(".txt"):
        # Extract the base filename (without extension)
        base_name = os.path.splitext(label_file)[0]
        # Construct the corresponding .tif filename
        tif_filename = f"{base_name}.tif"
        # Construct the source .tif path
        source_tif_path = os.path.join(source_image_dir, tif_filename)
        # Construct the destination symlink path
        destination_tif_path = os.path.join(destination_image_dir, tif_filename)

        # Check if the corresponding .tif exists in the source directory
        if os.path.exists(source_tif_path):
            # Create a symbolic link in the destination directory
            if not os.path.exists(destination_tif_path):  # Avoid overwriting existing symlinks
                os.symlink(source_tif_path, destination_tif_path)
                print(f"Linked {source_tif_path} -> {destination_tif_path}")
            else:
                print(f"Symlink already exists for {destination_tif_path}")
        else:
            print(f"File not found: {source_tif_path}")

print(f"All matching .tif files have been symlinked to {destination_image_dir}")
# Out:
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/8988385_3140642.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/8988385_3140642.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9021406_3113124.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9021406_3113124.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/8999392_3085607.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/8999392_3085607.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9032413_3107621.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9032413_3107621.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9021406_3115876.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9021406_3115876.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9029661_3107621.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9029661_3107621.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9004895_3118628.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9004895_3118628.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9035164_3091111.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9035164_3091111.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9037916_3088359.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9037916_3088359.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9035164_3088359.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9035164_3088359.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/8988385_3137890.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/8988385_3137890.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/8999392_3082855.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/8999392_3082855.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9040668_3088359.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9040668_3088359.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9002144_3118628.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9002144_3118628.tif
# Linked /home/patel_zeel/kiln_compass_24/data/lucknow_airshed/images/9024157_3085607.tif -> ../data/vlm_data/lucknow_airshed_most_15/images/9024157_3085607.tif
# All matching .tif files have been symlinked to ../data/vlm_data/lucknow_airshed_most_15/images
